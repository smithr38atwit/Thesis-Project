# %%
import gym

import rware

env: gym.Env = gym.make("rware-tiny-2ag-v1", n_people=1)
env.reset()
img = env.render(mode="rgb_array")
env.close()

# %%
from utils.images import plot_environment
import matplotlib.pyplot as plt

plot_environment(img)
plt.show()
